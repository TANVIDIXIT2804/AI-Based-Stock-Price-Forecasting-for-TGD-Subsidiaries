# %%
print('Hello World!')
print('NO')
# Out:
# Hello World!
# NO

# %%
# !unzip forecasting.zip
# Out:
# Archive:  forecasting.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of forecasting.zip or
#         forecasting.zip.zip, and cannot find forecasting.zip.ZIP, period.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/train.csv')
df.head()
# Out:
#         dates  Factor A  Factor B  Factor C  Factor D  Factor E  Factor F  \
# 0  1700-01-01    502.52    498.78    493.98     947.6    505.24   79050.0
# 1  1700-01-02    503.33    495.09    496.93     928.6    506.21   31082.0
# 2  1700-01-03    500.62    493.71    504.75     935.5    505.51   19375.0
# 3  1700-01-04    502.08    492.98    502.20     923.5    505.25   22010.0
# 4  1700-01-05    502.81    493.23    499.57     918.1    504.86   26533.0
#
#    Factor G  Factor H  Factor I  Factor J  Factor K  Factor L  Factor M  \
# 0    502.10    502.73    630.41    496.60    508.95    512.01    499.20
# 1    502.28    501.96    630.61    496.76    508.97    512.45    500.14
# 2    502.09    499.17    630.81    496.91    508.99    513.31    499.96
# 3    501.88    500.43    631.01    497.06    509.01    513.49    500.05
# 4    501.70    501.46    631.21    497.21    509.03    513.59    500.31
#
#    Factor N  TGD Consultancy Share price  TGD Automobiles Share price  \
# ...

# %%
df = pd.read_csv('/content/test.csv')
df.head()
# Out:
#         dates  Factor A  Factor B  Factor C  Factor D  Factor E    Factor F  \
# 0  2142-11-28  10499.99  10499.99  10499.99  100499.9   1499.99  10000500.0
# 1  2142-11-29  10499.99  10499.99  10499.99  100499.9   1499.99  10000500.0
# 2  2142-11-30  10499.99  10499.99  10499.99  100499.9   1499.99  10000500.0
# 3  2142-12-01  10499.99  10499.99  10499.99  100499.9   1499.99  10000500.0
# 4  2142-12-02    503.94    497.55    499.63     894.7    502.82     94705.0
#
#    Factor G  Factor H  Factor I  Factor J  Factor K  Factor L  Factor M  \
# 0    599.99   1499.99  10499.99  10499.99  10499.99  10499.99  10499.99
# 1    599.99   1499.99  10499.99  10499.99  10499.99  10499.99  10499.99
# 2    599.99   1499.99  10499.99  10499.99  10499.99  10499.99  10499.99
# 3    599.99   1499.99  10499.99  10499.99  10499.99  10499.99  10499.99
# 4    500.88    499.93    736.35    596.33    498.68    514.90    499.69
#
#    Factor N
# 0  10499.99
# 1  10499.99
# 2  10499.99
# 3  10499.99
# ...

# %% [markdown]
# Random 1600 datapoints liye

# %%
import pandas as pd
import random
p = 0.01  # 5% of the lines
# keep the header, then take only 1% of lines
# if random from [0,1] interval is greater than 0.01 the row will be skipped
df = pd.read_csv(
         '/content/train.csv',
         header=0, 
         skiprows=lambda i: i>0 and random.random() > p
)
df.to_csv('random_data.csv', index=False)

# %% [markdown]
# Plotted share price trends for those 1600 points

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [15, 5]
plt.rcParams["figure.autolayout"] = True

headers = ["dates","TGD Consultancy Share price", "TGD Automobiles Share price","TGD Power Share price"]

# consultancy = df["TGD Consultancy Share price"]
# automobile = df["TGD Automobiles Share price"]
# power = df["TGD Power Share price"]

df = pd.read_csv('/content/random_data.csv', usecols = headers)

df.set_index('dates').plot()


plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [15, 5]
plt.rcParams["figure.autolayout"] = True

headers = ["dates","Factor A"]

# consultancy = df["TGD Consultancy Share price"]
# automobile = df["TGD Automobiles Share price"]
# power = df["TGD Power Share price"]

df = pd.read_csv('/content/random_data.csv', usecols = headers)

df.set_index('dates').plot()


plt.show()

# %%
import pandas as pd
import random
p = 0.01  # 1% of the lines
# keep the header, then take only 1% of lines
# if random from [0,1] interval is greater than 0.01 the row will be skipped
df = pd.read_csv(
         '/content/train.csv',
         header=0, 
         skiprows=lambda i: i>0 and random.random() > p
)
df.to_csv('random_data.csv', index=False)

# %% [markdown]
# Factor F, Factor D  - outliers h kaafi

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [15, 5]
plt.rcParams["figure.autolayout"] = True

headers = ["dates","Factor A", "Factor C"]

# consultancy = df["TGD Consultancy Share price"]
# automobile = df["TGD Automobiles Share price"]
# power = df["TGD Power Share price"]

df = pd.read_csv('/content/aur_chota_data.csv', usecols = headers)

df.set_index('dates').plot()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [15, 5]
plt.rcParams["figure.autolayout"] = True

# headers = ["dates","Factor A", "Factor C"]

# consultancy = df["TGD Consultancy Share price"]
# automobile = df["TGD Automobiles Share price"]
# power = df["TGD Power Share price"]

df = pd.read_csv('/content/random_data.csv')

# df.set_index('dates').plot()
# plt.show()

# %%
df.head()
# Out:
#    Factor A  Factor B  Factor C  Factor D  Factor E  Factor F  Factor G  \
# 0    495.92    502.14    502.90     920.4    505.00   37066.0    501.77
# 1    497.34    501.30    502.58    1227.8    501.21  235522.0    501.29
# 2    494.70    500.46    501.69    1125.3    501.75  188857.0    501.37
# 3    496.36    502.87    501.19     869.5    504.70   67537.0    501.28
# 4    505.36    499.94    500.54     875.5    503.80   73661.0    501.07
#
#    Factor H  Factor I  Factor J  Factor K  Factor L  Factor M  Factor N  \
# 0    498.63    740.87    484.59    523.75    513.10    498.84    500.80
# 1    498.53    738.98    473.08    521.68    513.76    499.16    499.95
# 2    498.90    738.70    470.19    520.47    513.51    498.24    500.43
# 3    499.11    737.76    466.88    517.98    514.20    499.22    500.11
# 4    499.76    735.61    464.28    514.43    514.40    498.46    499.85
#
#    TGD Consultancy Share price  TGD Automobiles Share price  \
# ...

# %%
dfa = pd.read_csv('/content/aur_chota_data.csv', usecols = headers)
avg = dfa["Factor A"].mean()
dfa["Factor A"] = dfa["Factor A"].apply(lambda v: avg if v>=550 else v)
print(dfa.iloc[15])
# Out:
# dates        1745-08-30
# Factor A    1095.349821
# Factor C       10499.99
# Name: 15, dtype: object

# %%
pip install keras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dropout, Flatten

# %%
col=['dates']
new_df= df.drop(columns=col)
df = new_df.astype(float)
df.head(10)
# Out:
#    Factor A  Factor B  Factor C  Factor D  Factor E  Factor F  Factor G  \
# 0    495.92    502.14    502.90     920.4    505.00   37066.0    501.77
# 1    497.34    501.30    502.58    1227.8    501.21  235522.0    501.29
# 2    494.70    500.46    501.69    1125.3    501.75  188857.0    501.37
# 3    496.36    502.87    501.19     869.5    504.70   67537.0    501.28
# 4    505.36    499.94    500.54     875.5    503.80   73661.0    501.07
# 5    503.18    493.67    499.28     840.8    503.79   25296.0    500.88
# 6    499.19    501.87    500.11     777.0    511.32   13151.0    501.74
# 7    496.39    502.18    496.93     866.1    525.40   32698.0    506.81
# 8    496.22    507.83    496.50    1098.3    504.03  197482.0    502.88
# 9    500.51    501.18    494.92     999.8    506.13   54617.0    503.05
#
#    Factor H  Factor I  Factor J  Factor K  Factor L  Factor M  Factor N  \
# 0    498.63    740.87    484.59    523.75    513.10    498.84    500.80
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler = scaler.fit(df)
df_scaled = scaler.transform(df)

# %%
df_scaled
# Out:
# array([[0.00166156, 0.00225738, 0.00434431, ..., 0.25429553, 0.18888889,
#         0.015     ],
#        [0.00180326, 0.00217355, 0.00431244, ..., 0.27147766, 0.33333333,
#         0.0375    ],
#        [0.00153981, 0.00208972, 0.0042238 , ..., 0.24398625, 0.11111111,
#         0.01      ],
#        ...,
#        [0.00207071, 0.00216158, 0.0043712 , ..., 0.21649485, 0.07777778,
#         0.0075    ],
#        [0.00176135, 0.00239809, 0.00405151, ..., 0.21305842, 0.07777778,
#         0.0075    ],
#        [0.00244893, 0.00194402, 0.00411325, ..., 0.21993127, 0.03333333,
#         0.005     ]])

# %%
X=np.array(df_scaled)
print(X)
# Out:
# [[0.00166156 0.00225738 0.00434431 ... 0.25429553 0.18888889 0.015     ]
#  [0.00180326 0.00217355 0.00431244 ... 0.27147766 0.33333333 0.0375    ]
#  [0.00153981 0.00208972 0.0042238  ... 0.24398625 0.11111111 0.01      ]
#  ...
#  [0.00207071 0.00216158 0.0043712  ... 0.21649485 0.07777778 0.0075    ]
#  [0.00176135 0.00239809 0.00405151 ... 0.21305842 0.07777778 0.0075    ]
#  [0.00244893 0.00194402 0.00411325 ... 0.21993127 0.03333333 0.005     ]]

# %%
import numpy as np
np.random.seed(1)
from tensorflow.random import set_seed 
set_seed(2)
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential, load_model
from keras.layers.core import Dense
from keras.layers import LSTM
from keras import optimizers
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
import datetime as dt
import time
plt.style.use('ggplot')

# %%
# Setting up an early stop
earlystop = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=80,  verbose=1, mode='min')
callbacks_list = [earlystop]

# %%
#Build and train the model

def fit_model(train,test,timesteps,hl,lr,batch,epochs):
    X_train = []
    Y_train = []
    X_val = []
    Y_val = []
    
    timesteps =50
    hl = [40,35]
    lr = 1e-3
    batch_size = 64
    num_epochs = 250
  
    # Loop for training data
    for i in range(timesteps,train.shape[0]):
        X_train.append(train[(i-timesteps):i])
        Y_train.append(train[i][0])
    X_train,Y_train = np.array(X_train),np.array(Y_train)
  
    # Loop for val data
    for i in range(timesteps,test.shape[0]):
        X_val.append(test[i-timesteps:i])
        Y_val.append(test[i][0])
    X_val,Y_val = np.array(X_val),np.array(Y_val)
    
    # Adding Layers to the model
    model = Sequential()
    model.add(LSTM(X_train.shape[2],input_shape = (X_train.shape[1],X_train.shape[2]),return_sequences = True,
                   activation = 'relu'))
    for i in range(len(hl)-1):        
        model.add(LSTM(hl[i],activation = 'relu',return_sequences = True))

    model.add(LSTM(hl[-1],activation = 'relu'))
    model.add(Dense(1))
    model.compile(optimizer = optimizers.Adam(lr = lr), loss = 'mean_squared_error')
    #print(model.summary())
  
    # Training the data
    history = model.fit(X_train,Y_train,epochs = epochs,batch_size = batch,validation_data = (X_val, Y_val),verbose = 0,
                        shuffle = False, callbacks=callbacks_list)
    model.reset_states()
    return model, history.history['loss'], history.history['val_loss']

# %%
model,train_error,test_error = fit_model(train,test,num_epochs,timesteps,hl,lr,batch_size)
plot_error(train_error,test_error)
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-5ee7a36b92a2> in <cell line: 1>()
# ----> 1 model,train_error,test_error = fit_model(train,test,num_epochs,timesteps,hl,lr,batch_size)
# ...

# %%
def evaluate_model(model,test,timesteps):
    X_test = []
    Y_test = []

    # Loop for testing data
    for i in range(timesteps,test.shape[0]):
        X_test.append(test[i-timesteps:i])
        Y_test.append(test[i][0])
    X_test,Y_test = np.array(X_test),np.array(Y_test)
    #print(X_test.shape,Y_test.shape)
  
    # Prediction Time !!!!
    Y_hat = model.predict(X_test)
    mse = mean_squared_error(Y_test,Y_hat)
    rmse = sqrt(mse)
    r = r2_score(Y_test,Y_hat)
    return mse, rmse, r, Y_test, Y_hat

# %%
# Plotting the training errors
def plot_error(train_loss,val_loss):
    plt.plot(train_loss,c = 'r')
    plt.plot(val_loss,c = 'b')
    plt.ylabel('Loss')
    plt.legend(['train','val'],loc = 'upper right')
    plt.show()

# %%
# Extracting the series
series = df[['TGD Consultancy Share price','TGD Automobiles Share price','TGD Power Share price']] # Picking the series with high correlation
print(series.shape)
print(series.tail())
# Out:
# (1655, 3)
#       TGD Consultancy Share price  TGD Automobiles Share price  \
# 1650                        517.0                        427.0
# 1651                        508.0                        410.0
# 1652                        504.0                        407.0
# 1653                        503.0                        407.0
# 1654                        505.0                        403.0
#
#       TGD Power Share price
# 1650                  512.0
# 1651                  504.0
# 1652                  503.0
# 1653                  503.0
# 1654                  502.0

# %%
import pandas as pd
import random
p = 0.1  # 10% of the lines
# keep the header, then take only 1% of lines
# if random from [0,1] interval is greater than 0.01 the row will be skipped
df = pd.read_csv(
         '/content/random_data.csv',
         header=0, 
         skiprows=lambda i: i>0 and random.random() > p
)
df.to_csv('random_data_val.csv', index=False)

# %%
df_val = pd.read_csv('/content/random_data_val.csv')
df_val.tail()
# Out:
#           dates  Factor A  Factor B  Factor C  Factor D  Factor E  Factor F  \
# 156  2131-01-05    499.83    499.20    500.83     956.7    505.44  117015.0
# 157  2131-07-16    501.00    502.44    496.26     825.6    508.57   20016.0
# 158  2135-12-12    502.09    497.88    501.96    1018.0    503.28  154367.0
# 159  2137-08-26    503.97    495.71    501.67    1080.3    504.10  255980.0
# 160  2141-12-10    501.42    504.93    499.93     906.1    510.07   75549.0
#
#      Factor G  Factor H  Factor I  Factor J  Factor K  Factor L  Factor M  \
# 156    502.27    499.63    727.11    596.93    498.57    512.80    499.10
# 157    501.81    500.74    737.22    584.25    501.53    512.87    498.85
# 158    501.76    499.65    742.06    530.95    493.01    513.88    498.63
# 159    502.76    500.19    706.15    418.93    500.69    512.57    499.00
# 160    503.33    500.54    720.71    601.58    494.27    512.10    499.40
#
# ...

# %%
import pandas as pd
import random
p = 0.0068  # 1% of the lines
# keep the header, then take only 1% of lines
# if random from [0,1] interval is greater than 0.01 the row will be skipped
df = pd.read_csv(
         '/content/test.csv',
         header=0, 
         skiprows=lambda i: i>0 and random.random() > p
)
df.to_csv('random_data_test.csv', index=False)

# %%
df_te = pd.read_csv('/content/random_data_test.csv')
df_te.tail()
# Out:
#           dates  Factor A  Factor B  Factor C  Factor D  Factor E    Factor F  \
# 215  2222-12-09    500.25    500.56    498.85     892.6    502.25     42063.0
# 216  2223-12-04  10499.99  10499.99  10499.99  100499.9   1499.99  10000500.0
# 217  2224-01-09    501.83    494.34    499.08     808.7    507.61     14778.0
# 218  2224-06-14    503.54    500.03    502.16     845.9    509.70     43889.0
# 219  2224-06-22  10499.99  10499.99  10499.99  100499.9   1499.99  10000500.0
#
#      Factor G  Factor H  Factor I  Factor J  Factor K  Factor L  Factor M  \
# 215    500.69    500.46    701.45    583.52    495.14    515.16    499.50
# 216    599.99   1499.99  10499.99  10499.99  10499.99  10499.99  10499.99
# 217    501.45    499.84    716.69    602.44    501.89    513.91    499.12
# 218    502.32    499.29    724.20    599.02    504.68    512.84    499.07
# 219    599.99   1499.99  10499.99  10499.99  10499.99  10499.99  10499.99
#
#      Factor N
# 215    499.67
# 216  10499.99
# ...

# %%
col=['dates']
new_df= df.drop(columns=col)
df = new_df.astype(float)

# %%
col=['dates']
new_df= df_te.drop(columns=col)
df_te = new_df.astype(float)

# %%
col=['dates']
new_df= df_val.drop(columns=col)
df_val_n = new_df.astype(float)

# %%
df_val_n.tail()
# Out:
#      Factor A  Factor B  Factor C  Factor D  Factor E  Factor F  Factor G  \
# 156    499.83    499.20    500.83     956.7    505.44  117015.0    502.27
# 157    501.00    502.44    496.26     825.6    508.57   20016.0    501.81
# 158    502.09    497.88    501.96    1018.0    503.28  154367.0    501.76
# 159    503.97    495.71    501.67    1080.3    504.10  255980.0    502.76
# 160    501.42    504.93    499.93     906.1    510.07   75549.0    503.33
#
#      Factor H  Factor I  Factor J  Factor K  Factor L  Factor M  Factor N  \
# 156    499.63    727.11    596.93    498.57    512.80    499.10    500.55
# 157    500.74    737.22    584.25    501.53    512.87    498.85    500.29
# 158    499.65    742.06    530.95    493.01    513.88    498.63    500.32
# 159    500.19    706.15    418.93    500.69    512.57    499.00    500.41
# 160    500.54    720.71    601.58    494.27    512.10    499.40    499.91
#
#      TGD Consultancy Share price  TGD Automobiles Share price  \
# ...

# %%
# Normalisation
sc = MinMaxScaler()

train = sc.fit_transform(df)

test = sc.transform(df_te)
#val = sc.transform(df_val_n)
print(train.shape,test.shape)
# Out:
# (220, 14) (220, 14)

# %%
timesteps =50
hl = [40,35]
lr = 1e-3
batch_size = 64
num_epochs = 250

# %%
model,train_error,test_error = fit_model(train,test,num_epochs,timesteps,hl,lr,batch_size)
plot_error(train_error,test_error)
# Out:
# [] []
# (0,) (0,)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-86-5ee7a36b92a2> in <cell line: 1>()
# ----> 1 model,train_error,test_error = fit_model(train,test,num_epochs,timesteps,hl,lr,batch_size)
#       2 plot_error(train_error,test_error)
#
# <ipython-input-85-ee697f52ad1d> in fit_model(train, test, timesteps, hl, lr, batch, epochs)
#      23     # Adding Layers to the model
#      24     model = Sequential()
# ---> 25     model.add(LSTM(X_train.shape[2],input_shape = (X_train.shape[1],X_train.shape[2]),return_sequences = True,
#      26                    activation = 'relu'))
#      27     for i in range(len(hl)-1):
#
# IndexError: tuple index out of range

# %%
mse, rmse, r2_value,true,predicted = evaluate_model(model,test,timesteps)
print('MSE = {}'.format(mse))
print('RMSE = {}'.format(rmse))
print('R-Squared Score = {}'.format(r2_value))
plot_data(true,predicted)

# %% [markdown]
# ##Ab linear regression se karte hai

# %%
# !unzip forecasting.zip
# Out:
# Archive:  forecasting.zip
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
import numpy as np
import seaborn as sns
import os

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.feature_selection import RFECV, SelectFromModel, SelectKBest
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
# %matplotlib inline

# %%
Stock = pd.read_csv('/content/train.csv',  index_col=0)

df_Stock = Stock
df_Stock.head()
# Out:
#             Factor A  Factor B  Factor C  Factor D  Factor E  Factor F  \
# dates
# 1700-01-01    502.52    498.78    493.98     947.6    505.24   79050.0
# 1700-01-02    503.33    495.09    496.93     928.6    506.21   31082.0
# 1700-01-03    500.62    493.71    504.75     935.5    505.51   19375.0
# 1700-01-04    502.08    492.98    502.20     923.5    505.25   22010.0
# 1700-01-05    502.81    493.23    499.57     918.1    504.86   26533.0
#
#             Factor G  Factor H  Factor I  Factor J  Factor K  Factor L  \
# dates
# 1700-01-01    502.10    502.73    630.41    496.60    508.95    512.01
# 1700-01-02    502.28    501.96    630.61    496.76    508.97    512.45
# 1700-01-03    502.09    499.17    630.81    496.91    508.99    513.31
# 1700-01-04    501.88    500.43    631.01    497.06    509.01    513.49
# 1700-01-05    501.70    501.46    631.21    497.21    509.03    513.59
#
#             Factor M  Factor N  TGD Consultancy Share price  \
# dates
# ...

# %%
df_Stock.tail(5)
# Out:
#             Factor A  Factor B  Factor C  Factor D  Factor E    Factor F  \
# dates
# 2142-11-23  10499.99  10499.99  10499.99  100499.9   1499.99  10000500.0
# 2142-11-24  10499.99  10499.99  10499.99  100499.9   1499.99  10000500.0
# 2142-11-25  10499.99  10499.99  10499.99  100499.9   1499.99  10000500.0
# 2142-11-26  10499.99  10499.99  10499.99  100499.9   1499.99  10000500.0
# 2142-11-27  10499.99  10499.99  10499.99  100499.9   1499.99  10000500.0
#
#             Factor G  Factor H  Factor I  Factor J  Factor K  Factor L  \
# dates
# 2142-11-23    599.99   1499.99  10499.99  10499.99  10499.99  10499.99
# 2142-11-24    599.99   1499.99  10499.99  10499.99  10499.99  10499.99
# 2142-11-25    599.99   1499.99  10499.99  10499.99  10499.99  10499.99
# 2142-11-26    599.99   1499.99  10499.99  10499.99  10499.99  10499.99
# 2142-11-27    599.99   1499.99  10499.99  10499.99  10499.99  10499.99
#
#             Factor M  Factor N  TGD Consultancy Share price  \
# dates
# ...

# %%
df_Stock.shape
# Out:
# (161768, 17)

# %%
df_Stock.columns
# Out:
# Index(['Factor A', 'Factor B', 'Factor C', 'Factor D', 'Factor E', 'Factor F',
#        'Factor G', 'Factor H', 'Factor I', 'Factor J', 'Factor K', 'Factor L',
#        'Factor M', 'Factor N', 'TGD Consultancy Share price',
#        'TGD Automobiles Share price', 'TGD Power Share price'],
#       dtype='object')

# %%
df_Stock['TGD Consultancy Share price'].plot(figsize=(10, 7))
plt.title("Stock Price", fontsize=17)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Dates', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
def create_train_test_set(df_Stock):
    
    features = df_Stock.drop(columns=['TGD Consultancy Share price'], axis=1)
    target = df_Stock['TGD Consultancy Share price']
    

    data_len = df_Stock.shape[0]
    print('Historical Stock Data length is - ', str(data_len))

    #create a chronological split for train and testing
    train_split = int(data_len * 0.80)
    print('Training Set length - ', str(train_split))

    val_split = train_split + int(data_len * 0.1)
    print('Validation Set length - ', str(int(data_len * 0.1)))

    print('Test Set length - ', str(int(data_len * 0.1)))

    # Splitting features and target into train, validation and test samples 
    X_train, X_val, X_test = features[:train_split], features[train_split:val_split], features[val_split:]
    Y_train, Y_val, Y_test = target[:train_split], target[train_split:val_split], target[val_split:]

    #print shape of samples
    print(X_train.shape, X_val.shape, X_test.shape)
    print(Y_train.shape, Y_val.shape, Y_test.shape)
    
    return X_train, X_val, X_test, Y_train, Y_val, Y_test

# %%
X_train, X_val, X_test, Y_train, Y_val, Y_test = create_train_test_set(df_Stock)
# Out:
# Historical Stock Data length is -  161768
# Training Set length -  129414
# Validation Set length -  16176
# Test Set length -  16176
# (129414, 16) (16176, 16) (16178, 16)
# (129414,) (16176,) (16178,)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
print('LR Coefficients: \n', lr.coef_)
print('LR Intercept: \n', lr.intercept_)
# Out:
# LR Coefficients:
#  [ 1.48070991e-03  8.53138699e-03 -7.13953023e-02  8.29492680e-04
#   1.56175534e-01  5.25230084e-09 -1.20369317e-02 -1.48730275e-03
#  -5.20635717e-03  6.06151945e-03 -2.44654402e-02  1.24121647e-01
#   3.30709252e-01 -3.93332815e-01  2.19012581e-01  6.01370039e-01]
# LR Intercept:
#  52.06188680160943

# %%
print("Performance (R^2): ", lr.score(X_train, Y_train))
# Out:
# Performance (R^2):  0.40124317939006127

# %%
def get_mape(y_true, y_pred): 
    """
    Compute mean absolute percentage error (MAPE)
    """
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
Y_train_pred = lr.predict(X_train)
Y_val_pred = lr.predict(X_val)
Y_test_pred = lr.predict(X_test)

# %%
print("Training R-squared: ",round(metrics.r2_score(Y_train,Y_train_pred),2))
print("Training Explained Variation: ",round(metrics.explained_variance_score(Y_train,Y_train_pred),2))
print('Training MAPE:', round(get_mape(Y_train,Y_train_pred), 2)) 
print('Training Mean Squared Error:', round(metrics.mean_squared_error(Y_train,Y_train_pred), 2)) 
print("Training RMSE: ",round(np.sqrt(metrics.mean_squared_error(Y_train,Y_train_pred)),2))
print("Training MAE: ",round(metrics.mean_absolute_error(Y_train,Y_train_pred),2))

print(' ')

print("Validation R-squared: ",round(metrics.r2_score(Y_val,Y_val_pred),2))
print("Validation Explained Variation: ",round(metrics.explained_variance_score(Y_val,Y_val_pred),2))
print('Validation MAPE:', round(get_mape(Y_val,Y_val_pred), 2)) 
print('Validation Mean Squared Error:', round(metrics.mean_squared_error(Y_train,Y_train_pred), 2)) 
print("Validation RMSE: ",round(np.sqrt(metrics.mean_squared_error(Y_val,Y_val_pred)),2))
print("Validation MAE: ",round(metrics.mean_absolute_error(Y_val,Y_val_pred),2))

print(' ')

print("Test R-squared: ",round(metrics.r2_score(Y_test,Y_test_pred),2))
print("Test Explained Variation: ",round(metrics.explained_variance_score(Y_test,Y_test_pred),2))
print('Test MAPE:', round(get_mape(Y_test,Y_test_pred), 2)) 
print('Test Mean Squared Error:', round(metrics.mean_squared_error(Y_test,Y_test_pred), 2)) 
print("Test RMSE: ",round(np.sqrt(metrics.mean_squared_error(Y_test,Y_test_pred)),2))
print("Test MAE: ",round(metrics.mean_absolute_error(Y_test,Y_test_pred),2))
# Out:
# Training R-squared:  0.4
# Training Explained Variation:  0.4
# Training MAPE: 1.97
# Training Mean Squared Error: 242.67
# Training RMSE:  15.58
# Training MAE:  10.22
#
# Validation R-squared:  0.38
# Validation Explained Variation:  0.39
# Validation MAPE: 2.06
# Validation Mean Squared Error: 242.67
# Validation RMSE:  14.91
# Validation MAE:  10.64
#
# Test R-squared:  0.34
# Test Explained Variation:  0.36
# Test MAPE: 1.69
# Test Mean Squared Error: 140.45
# Test RMSE:  11.85
# Test MAE:  8.61

# %%
df_pred1 = pd.DataFrame(Y_val.values, columns=['Actual1'], index=Y_val.index)
df_pred1['Predicted1'] = Y_val_pred
df_pred1 = df_pred1.reset_index()
df_pred1.loc[:, 'dates'] = pd.to_datetime(df_pred1['dates'],format='%Y-%m-%d')
df_pred1
# Out:
# <ipython-input-17-6c8f26be9202>:4: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_pred1.loc[:, 'dates'] = pd.to_datetime(df_pred1['dates'],format='%Y-%m-%d')
#            dates  Actual1  Predicted1
# 0     2054-04-29    513.0  508.565245
# 1     2054-04-30    511.0  508.708654
# 2     2054-05-01    523.0  522.708210
# 3     2054-05-02    522.0  522.969852
# 4     2054-05-03    512.0  522.920352
# ...          ...      ...         ...
# 16171 2098-08-07    487.0  504.336966
# 16172 2098-08-08    491.0  509.475686
# 16173 2098-08-09    500.0  509.355596
# 16174 2098-08-10    503.0  509.395321
# 16175 2098-08-11    504.0  511.238415
#
# [16176 rows x 3 columns]

# %%
def create_train_test_set(df_Stock):
    
    features = df_Stock.drop(columns=['TGD Automobiles Share price'], axis=1)
    target = df_Stock['TGD Automobiles Share price']
    print(features)
    

    data_len = df_Stock.shape[0]
    print('Historical Stock Data length is - ', str(data_len))

    #create a chronological split for train and testing
    train_split2 = int(data_len * 0.80)
    print('Training Set length - ', str(train_split2))

    val_split2 = train_split2 + int(data_len * 0.1)
    print('Validation Set length - ', str(int(data_len * 0.1)))

    print('Test Set length - ', str(int(data_len * 0.1)))

    # Splitting features and target into train, validation and test samples 
    X_train2, X_val2, X_test2 = features[:train_split2], features[train_split2:val_split2], features[val_split2:]
    Y_train2, Y_val2,Y_test2 = target[:train_split2], target[train_split2:val_split2], target[val_split2:]

    #print shape of samples
    print(X_train2.shape, X_val2.shape, X_test2.shape)
    print(Y_train2.shape, Y_val2.shape,Y_test2.shape)
    
    return X_train2, X_val2, X_test2, Y_train2, Y_val2,Y_test2

# %%
X_train2, X_val2, X_test2, Y_train2, Y_val2, Y_test2 = create_train_test_set(df_Stock)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train2, Y_train2)
# Out:
# LinearRegression()

# %%
def get_mape(y_true2, y_pred2): 
    """
    Compute mean absolute percentage error (MAPE)
    """
    y_true2, y_pred2 = np.array(y_true2), np.array(y_pred2)
    return np.mean(np.abs((y_true2 - y_pred2) / y_true2)) * 100

# %%
Y_train_pred2 = lr.predict(X_train2)
Y_val_pred2 = lr.predict(X_val2)
Y_test_pred2 = lr.predict(X_test2)

# %%
print("Training R-squared: ",round(metrics.r2_score(Y_train2,Y_train_pred2),2))
print("Training Explained Variation: ",round(metrics.explained_variance_score(Y_train2,Y_train_pred2),2))
print('Training MAPE:', round(get_mape(Y_train2,Y_train_pred2), 2)) 
print('Training Mean Squared Error:', round(metrics.mean_squared_error(Y_train2,Y_train_pred2), 2)) 
print("Training RMSE: ",round(np.sqrt(metrics.mean_squared_error(Y_train2,Y_train_pred2)),2))
print("Training MAE: ",round(metrics.mean_absolute_error(Y_train2,Y_train_pred2),2))

print(' ')

print("Validation R-squared: ",round(metrics.r2_score(Y_val2,Y_val_pred2),2))
print("Validation Explained Variation: ",round(metrics.explained_variance_score(Y_val2,Y_val_pred2),2))
print('Validation MAPE:', round(get_mape(Y_val2,Y_val_pred2), 2)) 
print('Validation Mean Squared Error:', round(metrics.mean_squared_error(Y_train2,Y_train_pred2), 2)) 
print("Validation RMSE: ",round(np.sqrt(metrics.mean_squared_error(Y_val2,Y_val_pred2)),2))
print("Validation MAE: ",round(metrics.mean_absolute_error(Y_val2,Y_val_pred2),2))

print(' ')

print("Test R-squared: ",round(metrics.r2_score(Y_test2,Y_test_pred2),2))
print("Test Explained Variation: ",round(metrics.explained_variance_score(Y_test2,Y_test_pred2),2))
print('Test MAPE:', round(get_mape(Y_test2,Y_test_pred2), 2)) 
print('Test Mean Squared Error:', round(metrics.mean_squared_error(Y_test2,Y_test_pred2), 2)) 
print("Test RMSE: ",round(np.sqrt(metrics.mean_squared_error(Y_test2,Y_test_pred2)),2))
print("Test MAE: ",round(metrics.mean_absolute_error(Y_test2,Y_test_pred2),2))
# Out:
# Training R-squared:  0.64
# Training Explained Variation:  0.64
# Training MAPE: 1.57
# Training Mean Squared Error: 69.37
# Training RMSE:  8.33
# Training MAE:  6.61
#
# Validation R-squared:  0.69
# Validation Explained Variation:  0.7
# Validation MAPE: 1.5
# Validation Mean Squared Error: 69.37
# Validation RMSE:  7.39
# Validation MAE:  6.34
#
# Test R-squared:  0.67
# Test Explained Variation:  0.67
# Test MAPE: 1.58
# Test Mean Squared Error: 57.65
# Test RMSE:  7.59
# Test MAE:  6.6

# %%
df_pred2 = pd.DataFrame(Y_val2.values, columns=['Actual2'], index=Y_val2.index)
df_pred2['Predicted2'] = Y_val_pred2
df_pred2 = df_pred2.reset_index()
df_pred2.loc[:, 'dates'] = pd.to_datetime(df_pred2['dates'],format='%Y-%m-%d')
df_pred2
# Out:
# <ipython-input-24-c6db041f7556>:4: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_pred2.loc[:, 'dates'] = pd.to_datetime(df_pred2['dates'],format='%Y-%m-%d')
#            dates  Actual2  Predicted2
# 0     2054-04-29    417.0  414.594059
# 1     2054-04-30    417.0  414.563151
# 2     2054-05-01    437.0  424.687153
# 3     2054-05-02    437.0  425.004034
# 4     2054-05-03    437.0  424.218924
# ...          ...      ...         ...
# 16171 2098-08-07    407.0  412.038708
# 16172 2098-08-08    420.0  414.499737
# 16173 2098-08-09    420.0  415.060066
# 16174 2098-08-10    420.0  415.671102
# 16175 2098-08-11    423.0  416.962914
#
# [16176 rows x 3 columns]

# %%
def create_train_test_set(df_Stock):
    
    features = df_Stock.drop(columns=['TGD Power Share price'], axis=1)
    target = df_Stock['TGD Power Share price']
    print(features)
    

    data_len = df_Stock.shape[0]
    print('Historical Stock Data length is - ', str(data_len))

    #create a chronological split for train and testing
    train_split3 = int(data_len * 0.80)
    print('Training Set length - ', str(train_split3))

    val_split3 = train_split3 + int(data_len * 0.1)
    print('Validation Set length - ', str(int(data_len * 0.1)))

    print('Test Set length - ', str(int(data_len * 0.1)))

    # Splitting features and target into train, validation and test samples 
    X_train3, X_val3, X_test3 = features[:train_split3], features[train_split3:val_split3], features[val_split3:]
    Y_train3, Y_val3, Y_test3 = target[:train_split3], target[train_split3:val_split3], target[val_split3:]

    #print shape of samples
    print(X_train3.shape, X_val3.shape, X_test3.shape)
    print(Y_train3.shape, Y_val3.shape, Y_test3.shape)
    
    return X_train3, X_val3, X_test3, Y_train3, Y_val3, Y_test3

# %%
X_train3, X_val3, X_test3, Y_train3, Y_val3, Y_test3 = create_train_test_set(df_Stock)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train3, Y_train3)
# Out:
# LinearRegression()

# %%
def get_mape(y_true3, y_pred3): 
    """
    Compute mean absolute percentage error (MAPE)
    """
    y_true3, y_pred3 = np.array(y_true3), np.array(y_pred3)
    return np.mean(np.abs((y_true3 - y_pred3) / y_true3)) * 100

# %%
Y_train_pred3 = lr.predict(X_train3)
Y_val_pred3 = lr.predict(X_val3)
Y_test_pred3 = lr.predict(X_test3)

# %%
print("Training R-squared: ",round(metrics.r2_score(Y_train3,Y_train_pred3),2))
print("Training Explained Variation: ",round(metrics.explained_variance_score(Y_train3,Y_train_pred3),2))
print('Training MAPE:', round(get_mape(Y_train3,Y_train_pred3), 2)) 
print('Training Mean Squared Error:', round(metrics.mean_squared_error(Y_train3,Y_train_pred3), 2)) 
print("Training RMSE: ",round(np.sqrt(metrics.mean_squared_error(Y_train3,Y_train_pred3)),2))
print("Training MAE: ",round(metrics.mean_absolute_error(Y_train3,Y_train_pred3),2))

print(' ')

print("Validation R-squared: ",round(metrics.r2_score(Y_val3,Y_val_pred3),2))
print("Validation Explained Variation: ",round(metrics.explained_variance_score(Y_val3,Y_val_pred3),2))
print('Validation MAPE:', round(get_mape(Y_val3,Y_val_pred3), 2)) 
print('Validation Mean Squared Error:', round(metrics.mean_squared_error(Y_train3,Y_train_pred3), 2)) 
print("Validation RMSE: ",round(np.sqrt(metrics.mean_squared_error(Y_val3,Y_val_pred3)),2))
print("Validation MAE: ",round(metrics.mean_absolute_error(Y_val3,Y_val_pred3),2))

print(' ')

print("Test R-squared: ",round(metrics.r2_score(Y_test3,Y_test_pred3),2))
print("Test Explained Variation: ",round(metrics.explained_variance_score(Y_test3,Y_test_pred3),2))
print('Test MAPE:', round(get_mape(Y_test3,Y_test_pred3), 2)) 
print('Test Mean Squared Error:', round(metrics.mean_squared_error(Y_test3,Y_test_pred3), 2)) 
print("Test RMSE: ",round(np.sqrt(metrics.mean_squared_error(Y_test3,Y_test_pred3)),2))
print("Test MAE: ",round(metrics.mean_absolute_error(Y_test3,Y_test_pred3),2))
# Out:
# Training R-squared:  0.68
# Training Explained Variation:  0.68
# Training MAPE: 0.97
# Training Mean Squared Error: 91.11
# Training RMSE:  9.55
# Training MAE:  5.08
#
# Validation R-squared:  0.73
# Validation Explained Variation:  0.73
# Validation MAPE: 0.96
# Validation Mean Squared Error: 91.11
# Validation RMSE:  7.43
# Validation MAE:  4.97
#
# Test R-squared:  0.72
# Test Explained Variation:  0.72
# Test MAPE: 0.87
# Test Mean Squared Error: 42.28
# Test RMSE:  6.5
# Test MAE:  4.5

# %%
df_pred3 = pd.DataFrame(Y_val3.values, columns=['Actual3'], index=Y_val3.index)
df_pred3['Predicted3'] = Y_val_pred3
df_pred3 = df_pred3.reset_index()
df_pred3.loc[:, 'dates'] = pd.to_datetime(df_pred3['dates'],format='%Y-%m-%d')
df_pred3
# Out:
# <ipython-input-32-dd8043939a77>:4: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_pred3.loc[:, 'dates'] = pd.to_datetime(df_pred3['dates'],format='%Y-%m-%d')
#            dates  Actual3  Predicted3
# 0     2054-04-29    506.0  510.237860
# 1     2054-04-30    506.0  509.763534
# 2     2054-05-01    522.0  528.243656
# 3     2054-05-02    522.0  527.873569
# 4     2054-05-03    522.0  525.649739
# ...          ...      ...         ...
# 16171 2098-08-07    503.0  496.403223
# 16172 2098-08-08    507.0  507.502743
# 16173 2098-08-09    507.0  509.506239
# 16174 2098-08-10    507.0  510.007696
# 16175 2098-08-11    509.0  512.578484
#
# [16176 rows x 3 columns]

# %%
hc = pd.concat([df_pred1, df_pred2,df_pred3], axis=1)
 
display(hc)
# Out:
#            dates  Actual1  Predicted1      dates  Actual2  Predicted2  \
# 0     2054-04-29    513.0  508.565245 2054-04-29    417.0  414.594059
# 1     2054-04-30    511.0  508.708654 2054-04-30    417.0  414.563151
# 2     2054-05-01    523.0  522.708210 2054-05-01    437.0  424.687153
# 3     2054-05-02    522.0  522.969852 2054-05-02    437.0  425.004034
# 4     2054-05-03    512.0  522.920352 2054-05-03    437.0  424.218924
# ...          ...      ...         ...        ...      ...         ...
# 16171 2098-08-07    487.0  504.336966 2098-08-07    407.0  412.038708
# 16172 2098-08-08    491.0  509.475686 2098-08-08    420.0  414.499737
# 16173 2098-08-09    500.0  509.355596 2098-08-09    420.0  415.060066
# 16174 2098-08-10    503.0  509.395321 2098-08-10    420.0  415.671102
# 16175 2098-08-11    504.0  511.238415 2098-08-11    423.0  416.962914
#
#            dates  Actual3  Predicted3
# 0     2054-04-29    506.0  510.237860
# 1     2054-04-30    506.0  509.763534
# ...

# %%
hc['sum_pred'] = hc['Predicted1']+ hc['Predicted2'] + hc['Predicted3']
hc['sum_act'] = hc['Actual1']+ hc['Actual2'] + hc['Actual3']
hc
# Out:
#            dates  Actual1  Predicted1      dates  Actual2  Predicted2  \
# 0     2054-04-29    513.0  508.565245 2054-04-29    417.0  414.594059
# 1     2054-04-30    511.0  508.708654 2054-04-30    417.0  414.563151
# 2     2054-05-01    523.0  522.708210 2054-05-01    437.0  424.687153
# 3     2054-05-02    522.0  522.969852 2054-05-02    437.0  425.004034
# 4     2054-05-03    512.0  522.920352 2054-05-03    437.0  424.218924
# ...          ...      ...         ...        ...      ...         ...
# 16171 2098-08-07    487.0  504.336966 2098-08-07    407.0  412.038708
# 16172 2098-08-08    491.0  509.475686 2098-08-08    420.0  414.499737
# 16173 2098-08-09    500.0  509.355596 2098-08-09    420.0  415.060066
# 16174 2098-08-10    503.0  509.395321 2098-08-10    420.0  415.671102
# 16175 2098-08-11    504.0  511.238415 2098-08-11    423.0  416.962914
#
#            dates  Actual3  Predicted3          sum     sum_pred  sum_act
# ...

# %% [markdown]
# ###Model

# %%
# !unzip forecast.zip
# Out:
# Archive:  forecast.zip
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
import numpy as np
import seaborn as sns
import os

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.feature_selection import RFECV, SelectFromModel, SelectKBest
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
# %matplotlib inline

# %%
Stock = pd.read_csv('/content/train.csv',  index_col=0)
test = pd.read_csv('/content/test.csv',index_col=0)
df_test = test
df_Stock = Stock
df_Stock.head()
# Out:
#             Factor A  Factor B  Factor C  Factor D  Factor E  Factor F  \
# dates
# 1700-01-01    502.52    498.78    493.98     947.6    505.24   79050.0
# 1700-01-02    503.33    495.09    496.93     928.6    506.21   31082.0
# 1700-01-03    500.62    493.71    504.75     935.5    505.51   19375.0
# 1700-01-04    502.08    492.98    502.20     923.5    505.25   22010.0
# 1700-01-05    502.81    493.23    499.57     918.1    504.86   26533.0
#
#             Factor G  Factor H  Factor I  Factor J  Factor K  Factor L  \
# dates
# 1700-01-01    502.10    502.73    630.41    496.60    508.95    512.01
# 1700-01-02    502.28    501.96    630.61    496.76    508.97    512.45
# 1700-01-03    502.09    499.17    630.81    496.91    508.99    513.31
# 1700-01-04    501.88    500.43    631.01    497.06    509.01    513.49
# 1700-01-05    501.70    501.46    631.21    497.21    509.03    513.59
#
#             Factor M  Factor N  TGD Consultancy Share price  \
# dates
# ...

# %%
df_Stock.shape
df_test.shape
# Out:
# (30000, 14)

# %%
df_Stock.columns
# Out:
# Index(['Factor A', 'Factor B', 'Factor C', 'Factor D', 'Factor E', 'Factor F',
#        'Factor G', 'Factor H', 'Factor I', 'Factor J', 'Factor K', 'Factor L',
#        'Factor M', 'Factor N', 'TGD Consultancy Share price',
#        'TGD Automobiles Share price', 'TGD Power Share price'],
#       dtype='object')

# %%
df_Stock['TGD Consultancy Share price'].plot(figsize=(10, 7))
plt.title("Stock Price", fontsize=17)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Dates', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
# predictors = ["Factor A", "Factor B","Factor C","Factor D","Factor E","Factor F","Factor G","Factor H","Factor I","Factor J","Factor K","Factor L","Factor M","Factor N"]

# train = df_Stock.iloc[:]
# test = df_test.iloc[:]

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# Set the target variable
target_variable = 'TGD Consultancy Share price'

# Split the data into training and validation sets
train_size = int(len(df_Stock) * 0.85)
train_data = df_Stock[:train_size]
val_data = df_Stock[train_size:]

# Fit a linear regression model
model = LinearRegression()
model.fit(train_data.drop(target_variable, axis=1), train_data[target_variable])

# Get the feature importances
importances = np.abs(model.coef_)

# Sort the feature importances in descending order
sorted_importances = sorted(zip(df_Stock.columns.drop(target_variable), importances), key=lambda x: x[1], reverse=True)

# Print the top feature importances
print('Top feature importances for predicting', target_variable)
for feature, importance in sorted_importances[:10]:
    print(feature, ':', importance)
# Out:
# Top feature importances for predicting TGD Consultancy Share price
# TGD Power Share price : 0.597431235202486
# Factor N : 0.3747287543255185
# Factor M : 0.2812362595781363
# TGD Automobiles Share price : 0.2291852309529266
# Factor E : 0.1855830426993989
# Factor L : 0.15209273058274433
# Factor C : 0.06976228687332366
# Factor K : 0.0325910584849561
# Factor B : 0.022669041161877356
# Factor G : 0.012260560185605686

# %%
predictors1 = ['Factor M', 'Factor N', 'Factor L',  'Factor E', 'Factor C','Factor K', 'Factor B', 'Factor G']

train1 = df_Stock.iloc[:]
test1 = df_test.iloc[:]

# %%
# from sklearn.linear_model import LinearRegression

# lr = LinearRegression()
# lr.fit(train1[predictors1], train1["TGD Consultancy Share price"])
# Out:
# LinearRegression()

# %%
from sklearn.ensemble import RandomForestRegressor
 
 # create regressor object
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
 
# fit the regressor with x and y data
regressor.fit(train1[predictors1], train1["TGD Consultancy Share price"])

# %%
Y_test_pred1 = lr.predict(test1[predictors1])

# %%
preds1 = pd.DataFrame(Y_test_pred1,index=test.index, columns=["pred1"])
preds1
# Out:
#                  pred1
# dates
# 2142-11-28  511.528196
# 2142-11-29  511.528196
# 2142-11-30  511.528196
# 2142-12-01  511.528196
# 2142-12-02  511.597899
# ...                ...
# 2225-01-12  507.937151
# 2225-01-13  508.938238
# 2225-01-14  509.274675
# 2225-01-15  508.538785
# 2225-01-16  509.778683
#
# [30000 rows x 1 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# Set the target variable
target_variable = 'TGD Automobiles Share price'

# Split the data into training and validation sets
train_size = int(len(df_Stock) * 0.85)
train_data = df_Stock[:train_size]
val_data = df_Stock[train_size:]

# Fit a linear regression model
model = LinearRegression()
model.fit(train_data.drop(target_variable, axis=1), train_data[target_variable])

# Get the feature importances
importances = np.abs(model.coef_)

# Sort the feature importances in descending order
sorted_importances = sorted(zip(df_Stock.columns.drop(target_variable), importances), key=lambda x: x[1], reverse=True)

# Print the top feature importances
print('Top feature importances for predicting', target_variable)
for feature, importance in sorted_importances[:10]:
    print(feature, ':', importance)
# Out:
# Top feature importances for predicting TGD Automobiles Share price
# TGD Power Share price : 0.5988552988151036
# Factor M : 0.47731708719346283
# Factor L : 0.3068390772548675
# Factor N : 0.15506058797190714
# TGD Consultancy Share price : 0.06449372724556673
# Factor A : 0.05135808569457354
# Factor C : 0.04116902822845687
# Factor E : 0.03826038897289513
# Factor G : 0.014640500456487713
# Factor I : 0.008586266867387938

# %%
predictors2 = ['Factor M', 'Factor C', 'Factor N', 'Factor L', 'Factor A', 'Factor E', 'Factor G','Factor I']

train2 = df_Stock.iloc[:]
test2 = df_test.iloc[:]

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(train2[predictors2], train2["TGD Automobiles Share price"])
# Out:
# LinearRegression()

# %%
Y_test_pred2 = lr.predict(test2[predictors2])

# %%
preds2 = pd.DataFrame(Y_test_pred2,index=test.index, columns=["pred2"])
preds2
# Out:
#                  pred2
# dates
# 2142-11-28  418.123530
# 2142-11-29  418.123530
# 2142-11-30  418.123530
# 2142-12-01  418.123530
# 2142-12-02  417.003541
# ...                ...
# 2225-01-12  414.367748
# 2225-01-13  415.675867
# 2225-01-14  415.512179
# 2225-01-15  415.407677
# 2225-01-16  416.018720
#
# [30000 rows x 1 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# Set the target variable
target_variable = 'TGD Power Share price'

# Split the data into training and validation sets
train_size = int(len(df_Stock) * 0.85)
train_data = df_Stock[:train_size]
val_data = df_Stock[train_size:]

# Fit a linear regression model
model = LinearRegression()
model.fit(train_data.drop(target_variable, axis=1), train_data[target_variable])

# Get the feature importances
importances = np.abs(model.coef_)

# Sort the feature importances in descending order
sorted_importances = sorted(zip(df_Stock.columns.drop(target_variable), importances), key=lambda x: x[1], reverse=True)

# Print the top feature importances
print('Top feature importances for predicting', target_variable)
for feature, importance in sorted_importances[:10]:
    print(feature, ':', importance)
# Out:
# Top feature importances for predicting TGD Power Share price
# TGD Automobiles Share price : 0.787195762230231
# TGD Consultancy Share price : 0.22099356336326031
# Factor L : 0.16275671572453576
# Factor M : 0.13625641375842693
# Factor E : 0.03352233682864671
# Factor N : 0.030355642784991737
# Factor A : 0.029165104305801624
# Factor C : 0.018656175871211884
# Factor B : 0.006415019508634906
# Factor G : 0.004685912415425431

# %%
predictors3 = ['Factor M', 'Factor N', 'Factor L', 'Factor E','Factor A', 'Factor C','Factor B','Factor G']

train3 = df_Stock.iloc[:]
test3 = df_test.iloc[:]

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(train3[predictors3], train3["TGD Power Share price"])
# Out:
# LinearRegression()

# %%
Y_test_pred3 = lr.predict(test3[predictors3])

# %%
preds3 = pd.DataFrame(Y_test_pred3,index=test.index, columns=["pred3"])
preds3
# Out:
#                  pred3
# dates
# 2142-11-28  510.209448
# 2142-11-29  510.209448
# 2142-11-30  510.209448
# 2142-12-01  510.209448
# 2142-12-02  510.155551
# ...                ...
# 2225-01-12  506.861598
# 2225-01-13  508.155954
# 2225-01-14  508.196515
# 2225-01-15  507.855701
# 2225-01-16  508.502410
#
# [30000 rows x 1 columns]

# %%
hc = pd.concat([preds1, preds2,preds3], axis=1)
display(hc)
# Out:
#                  pred1       pred2       pred3
# dates
# 2142-11-28  511.528196  418.123530  510.209448
# 2142-11-29  511.528196  418.123530  510.209448
# 2142-11-30  511.528196  418.123530  510.209448
# 2142-12-01  511.528196  418.123530  510.209448
# 2142-12-02  511.597899  417.003541  510.155551
# ...                ...         ...         ...
# 2225-01-12  507.937151  414.367748  506.861598
# 2225-01-13  508.938238  415.675867  508.155954
# 2225-01-14  509.274675  415.512179  508.196515
# 2225-01-15  508.538785  415.407677  507.855701
# 2225-01-16  509.778683  416.018720  508.502410
#
# [30000 rows x 3 columns]

# %%
hc['Predicted'] = hc['pred1']+ hc['pred2'] + hc['pred3']
hc['Predicted']

output = pd.DataFrame(hc['Predicted'],index=test.index, columns=["Predicted"])
output
# Out:
#               Predicted
# dates
# 2142-11-28  1439.861173
# 2142-11-29  1439.861173
# 2142-11-30  1439.861173
# 2142-12-01  1439.861173
# 2142-12-02  1438.756992
# ...                 ...
# 2225-01-12  1429.166498
# 2225-01-13  1432.770059
# 2225-01-14  1432.983370
# 2225-01-15  1431.802163
# 2225-01-16  1434.299813
#
# [30000 rows x 1 columns]

# %%
output.to_csv('output.csv')

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
